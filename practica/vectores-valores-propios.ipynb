# %%
import numpy as np

# %%
A = [[-1,1,1], [1,-1,1], [1,1,-1]]

# %%
I = [[1,0,0], [0,1,0], [0,0,1]]

pc = A - 1*I
pc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 I = [[1,0,0], [0,1,0], [0,0,1]]
# ----> 3 pc = A - 1*I
#       4 pc
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
